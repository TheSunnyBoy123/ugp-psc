# %%
# load chatbot/data/column_embeddings.npz then generate embeddings for "which brand of substrate would work best", then do a cosine similarity and find which column would work best
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
# Load the column embeddings
column_embeddings = np.load('data/column_embeddings.npz')['embeddings']

# %%
query = "which brand of substrate would work best"
# generate embedding using sentence transformer
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')
query_embedding = model.encode([query])
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 10040.05it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import pandas as pd

df = pd.read_csv('data/perovskite_db_column_metadata.csv')

column_names = df["column_name"].tolist()

top_columns = [column_names[i] for i in top_indices]

# ensure correct shapes
query_embedding = query_embedding.reshape(1, -1)

similarity = cosine_similarity(query_embedding, column_embeddings)

top_indices = np.argsort(similarity[0])[::-1][:10]

top_columns = [column_names[i] for i in top_indices]

print("Top 10 most similar column names:", top_columns)
# Out:
# Top 10 most similar column names: ['Substrate_brand_name', 'Substrate_supplier', 'Substrate_cleaning_procedure', 'Substrate_stack_sequence', 'Substrate_surface_roughness_rms', 'Add_lay_back_deposition_solvents_supplier', 'Substrate_deposition_procedure', 'Substrate_etching_procedure', 'HTL_deposition_reaction_solutions_compounds_supplier', 'Add_lay_back_deposition_reaction_solutions_compounds_supplier']
